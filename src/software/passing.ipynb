# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas

# Import CSV without headers
data = pandas.read_csv('/tmp/tbots/blue/pass_optimizer_stats_.csv', header=None)
data
# Out:
#                   0             1
# 0      1.095840e-03  7.963720e-13
# 1      1.698920e-01  1.393360e-03
# 2      2.413400e-02  4.630620e-10
# 3      5.813090e-04  2.225130e-13
# 4      1.711760e-01  4.775350e-07
# ...             ...           ...
# 46633  0.000000e+00  0.000000e+00
# 46634  2.553460e-10  4.271750e-26
# 46635  0.000000e+00  0.000000e+00
# 46636  0.000000e+00  0.000000e+00
# 46637  2.768790e-10  5.022580e-26
#
# [46638 rows x 2 columns]

# %%
# Two histogram plots of the two unnamed column using matplotlib.

plt.hist(data[0], bins=10)  # density=False would make counts
plt.ylabel('count')
plt.xlabel('distance receiver position moved');

# %%
plt.hist(data[1], bins=50)  # density=False would make counts
plt.ylabel('count')
plt.xlabel('delta score after optimization');

# %%
plt.boxplot(data[0], vert=False, notch=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8e180d8820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8e17efdf70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8e18025b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8e17efdd60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8e17efd310>],
#  'means': []}
