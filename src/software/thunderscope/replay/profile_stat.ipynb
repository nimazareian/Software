# %%
import os
import gzip
from pathlib import Path

bytes_per_proto = {}

def parse_line(line):
    timestamp, protobuf_type, data = log_entry.split(
        bytes(",", encoding="utf-8")
    )
    if protobuf_type not in bytes_per_proto:
        bytes_per_proto[protobuf_type] = 0
    
    bytes_per_proto[protobuf_type] += len(data)

total_compressed_size = 0
for file in os.listdir("1min_blue_replay"):
    if file.endswith(".replay"):
        total_compressed_size += os.path.getsize("1min_blue_replay/" + file)
        with gzip.open("1min_blue_replay/" + file, "rb") as f:
            for log_entry in f:
                parse_line(log_entry)


print(f"Total compressed size: {total_compressed_size}")
total_decompressed_size = sum(bytes_per_proto.values())
print(f"Total decompressed size: {total_decompressed_size}")

print("\nSorted decompressed size per protobuf type:")
for key in sorted(bytes_per_proto, key=bytes_per_proto.get, reverse=True):
    print(f"{key}, {bytes_per_proto[key]} Bytes, {100 * (bytes_per_proto[key] / total_decompressed_size):.1f}%")
# Out:
# Total compressed size: 4219580
# Total decompressed size: 16985284
#
# Sorted decompressed size per protobuf type:
# b'TbotsProto.ObstacleList', 7258964 Bytes, 42.7%
# b'SSLProto.SSL_WrapperPacket', 3179688 Bytes, 18.7%
# b'TbotsProto.World', 2250832 Bytes, 13.3%
# b'TbotsProto.PathVisualization', 2152796 Bytes, 12.7%
# b'TbotsProto.PrimitiveSet', 1250240 Bytes, 7.4%
# b'TbotsProto.PlayInfo', 536456 Bytes, 3.2%
# b'TbotsProto.PassVisualization', 139784 Bytes, 0.8%
# b'TbotsProto.RobotLog', 117696 Bytes, 0.7%
# b'TbotsProto.NamedValue', 82924 Bytes, 0.5%
# b'TbotsProto.RobotStatus', 15020 Bytes, 0.1%
# b'SSLProto.Referee', 860 Bytes, 0.0%
# b'SSLProto.ManualGCCommand', 24 Bytes, 0.0%
